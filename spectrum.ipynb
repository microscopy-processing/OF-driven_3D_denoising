# %%
#tomogram_name = "empiar10311_stack_crop"
#tomogram_name = "empiar10311_stack_crop__sigma=2.0__w=5__l=3"
tomogram_name = "empiar10311_stack_crop__sigma=2.0"
#dir = "tomograms"
dir = "results"
input_format = "mrc"

# %%
# Mount Google Drive.
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import scipy.ndimage
import matplotlib.pyplot as plt
# !pip install mrcfile
import mrcfile
from ipywidgets import *
import cv2
from google.colab.patches import cv2_imshow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !cp drive/Shareddrives/TomogramDenoising/{dir}/{tomogram_name}.{input_format} .

# %%
tomogram_MRC = mrcfile.open(f'{tomogram_name}.{input_format}')
print(tomogram_MRC.data.dtype, tomogram_MRC.data.shape)
# Out:
# float32 (100, 1024, 1024)

# %%
def g(z=0):
  #cv2_imshow(cv2.normalize(tomogram[z, :, :][0:200,0:200].astype(np.uint8), None, 0, 255, cv2.NORM_MINMAX))
  #cv2_imshow(cv2.normalize(tomogram[z, :, :].astype(np.uint8), None, 0, 255, cv2.NORM_MINMAX))
  cv2_imshow(cv2.normalize(tomogram_MRC.data[z, :, :], None, 0, 255, cv2.NORM_MINMAX))
  fft_image = np.fft.fftshift(np.fft.fft2(tomogram_MRC.data[z, :, :]))
  cv2_imshow(cv2.normalize(np.log(abs(fft_image)), None, 0, 255, cv2.NORM_MINMAX))

interactive_plot = interactive(g, z=50)
interactive_plot
